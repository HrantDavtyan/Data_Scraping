# %%
import quandl

# %%
with open('quandl_key.txt','r') as f:
    key = f.read()

# %%
data_trade = quandl.get('RFSS/EXEXPIMP',authtoken=key)
data_trade.head()
# Out:
#             Exports (Bln USD)  Imports (Bln USD)  \
# Date
# 2000-12-31              103.1               33.9
# 2005-12-31              241.5               98.7
# 2009-12-31              301.7              167.3
# 2010-12-31              397.1              228.9
# 2011-12-31              516.7              305.8
#
#             :With CIS countries: Exports (Bln USD)  \
# Date
# 2000-12-31                                    13.8
# 2005-12-31                                    32.6
# 2009-12-31                                    46.8
# 2010-12-31                                    59.6
# 2011-12-31                                    79.4
#
#             :With CIS countries: Imports (Bln USD)  \
# Date
# 2000-12-31                                    11.6
# 2005-12-31                                    19.0
# 2009-12-31                                    21.8
# 2010-12-31                                    31.7
# 2011-12-31                                    44.8
#
# ...

# %%
data_trade_structure = quandl.get(['RFSS/EXCOMIMP','RFSS/EXCOMEXP'],authtoken=key)
data_trade_structure.head()
# Out:
#             RFSS/EXCOMIMP - Exports Total (Bln USD)  \
# Date
# 1995-12-31                                     46.7
# 2000-12-31                                     33.9
# 2005-12-31                                     98.7
# 2007-12-31                                    200.0
# 2008-12-31                                    267.0
#
#             RFSS/EXCOMIMP - :Foodstuffs and agricultural raw materials (excluding textile)  \
# Date
# 1995-12-31                                               13.2
# 2000-12-31                                                7.4
# 2005-12-31                                               17.4
# 2007-12-31                                               27.6
# 2008-12-31                                               35.2
#
#             RFSS/EXCOMIMP - :Mineral products  \
# Date
# 1995-12-31                                3.0
# 2000-12-31                                2.1
# 2005-12-31                                3.0
# ...
